# %% [markdown]
# #Incremental Data Loading Using AutoLoader

# %%
# %sql
CREATE SCHEMA netflix_catalog.net_schema

# %%
checkpoint_location = 'abfss://silver@netflixprojectdatalake.dfs.core.windows.net/checkpoint'

# %%
df = spark.readStream.format('cloudFiles')\
          .option("cloudFiles.format", "csv")\
          .option("cloudFiles.schemaLocation", checkpoint_location)\
          .load('abfss://raw@netflixprojectdatalake.dfs.core.windows.net')

# %%
df.limit(10).display()

# %%
df.writeStream.format('delta')\
     .option('checkpointLocation',checkpoint_location)\
     .trigger(processingTime = '10 seconds')\
     .start('abfss://bronze@netflixprojectdatalake.dfs.core.windows.net/netflix_titles')
